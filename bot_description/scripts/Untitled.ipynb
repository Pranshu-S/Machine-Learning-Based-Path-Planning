# %%
from scipy.optimize import fsolve
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7e54c6764195> in <module>
# ----> 1 from scipy.optimize import fsolve
#
# ModuleNotFoundError: No module named 'scipy'

# %%
2**3
# Out:
# 8
